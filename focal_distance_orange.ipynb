# %%
import cv2
import numpy as np
import imutils
cap = cv2.VideoCapture(1)    
lower = [0, 183, 171]
upper = [11, 255, 255]
'''lower = {'green': (60, 104, 107), 'yellow': (25, 70, 164), 'orange': (0, 241, 162),'pink':(155,119,110)}
upper = {'green': (80, 255, 255), 'yellow': (55, 255, 255), 'orange': (11, 255, 255),'pink':(179,255,255)}
#-9'''
cap.set(cv2.CAP_PROP_EXPOSURE, -8.5) 
'''def getBox(image):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    #edged = cv2.Canny(gray, 190, 200)
    #cv2.imshow('edge',edged)
    lower_blue = np.array(lower)
    upper_blue = np.array(upper)
    mask = cv2.inRange(hsv, lower_blue, upper_blue)
    blurred = cv2.GaussianBlur(frame, (5, 5), 0)
    erode_element = cv2.getStructuringElement(cv2.MORPH_RECT, (6, 6))
    dilate_element = cv2.getStructuringElement(cv2.MORPH_RECT, (6, 6))
    eroded_mask = cv2.erode(mask, erode_element)
    dilated_mask = cv2.dilate(eroded_mask, dilate_element)
    edged = cv2.Canny(dilated_mask, 190, 200)
    cnts = cv2.findContours(edged.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    if len(cnts) > 0:
        c = max(cnts, key = cv2.contourArea)
        return cv2.minEnclosingCircle(c)
'''
count=0
cm_array=[]
set_distance = 7.08661
set_width = 3.14961
set_pixel = 236.907
while True:      
    _, frame = cap.read()
    #gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    #gray = cv2.GaussianBlur(gray, (5, 5), 0)
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)
    lower_blue = np.array(lower)
    upper_blue = np.array(upper)
    mask = cv2.inRange(hsv, lower_blue, upper_blue)
    blurred = cv2.GaussianBlur(frame, (5, 5), 0)
    erode_element = cv2.getStructuringElement(cv2.MORPH_RECT, (6, 6))
    dilate_element = cv2.getStructuringElement(cv2.MORPH_RECT, (6, 6))
    eroded_mask = cv2.erode(mask, erode_element)
    dilated_mask = cv2.dilate(eroded_mask, dilate_element)
    #edged = cv2.Canny(dilated_mask, 40, 50)
    cv2.imshow('edge',dilated_mask)
    cnts = cv2.findContours(dilated_mask.copy(), cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    if len(cnts) > 0:
        c = max(cnts, key = cv2.contourArea)
        ((x,y),r) = cv2.minEnclosingCircle(c)
        focalLength = 533.0398
        inches = (set_width * focalLength) / (2*r)
        cm=2.54*inches
        cm_array.append(cm)
        count+=1
        total=0.0
        #print(cm_array)
        if(count==3):
            for ele in range(0, len(cm_array)): 
                total = total + cm_array[ele] 
            total = total/len(cm_array)
            count=0
            cm_array.clear()
            print(total)
        
        cv2.circle(frame, (int(x), int(y)), int(r),(0, 255, 255), 2)
        #cv2.putText(frame, "%.2fft" % (inches / 12),(frame.shape[1] - 200, frame.shape[0] - 20), cv2.FONT_HERSHEY_SIMPLEX,2.0, (0, 255, 0), 3)
        cv2.putText(frame, "%.2fcm" % (inches*2.54),(frame.shape[1] - 200, frame.shape[0] - 20), cv2.FONT_HERSHEY_SIMPLEX,2.0, (0, 255, 0), 3)
        cv2.imshow("image", frame)
        
        key = cv2.waitKey(1) & 0xFF      
        if key==ord('q'):
            break



cap.release()
cv2.destroyAllWindows()
# Out:
# 20.51871849475286
# 15.747638989963905
# 15.30345883206278
# 14.592197365447019
# 14.18707820123115
# 14.17187125775906
# 14.304336613220284
# 14.337145900956974
# 14.303368796690622
# 14.097660225934602
# 14.228479203970958
# 14.290894986291235
# 14.310964535564764
# 14.318281019833684
# 14.293901142886973
# 14.32854510453133
# 14.35458922649921
# 14.343860470839742
# 14.546862910642863
# 14.780609140541346
# 14.417466741790548
# 13.999522229190058
# 13.24097954615083
# 12.333475365944082
# 11.95836558899741
# 11.626623817286161
# 11.365177049046997
# 11.135352124624411
# 10.95013442174366
# 10.620437067975573
# 10.48590705701386
# 10.449978929038787
# 10.552135749399609
# 10.809346957911776
# 10.926680177232997
# 10.755593204008173
# 10.686612280452785
# 10.644861408022857
# 10.729717578527477
# 10.745673036354853
# 10.721930730927681
# 10.775305710314813
# 10.820387078455482
# 10.720561192401206
# 10.712672496914479
# 10.787586596571773
# 10.755456499890988
# 10.791100776945408
# ...
